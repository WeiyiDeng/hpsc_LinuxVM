# %% [markdown]
# # Lecture 5 demo by w
# ## hpsc week 2
# Try ploting $y = \frac{dy}{dx}$ and $y = cos(x)$ \n
# Markdown here, same as in LaTex

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(0,5*pi,100)
y = sin(x)

# %%
print(x[10])
# Out:
# 1.58666295636

# %%
print(y[0])
# Out:
# 0.0

# %%
plot(x,y)
plot(x,-y,'r:')
